# %%
import pandas as pd
import numpy as np
dates = pd.date_range('2023-01-01', periods=10)
data = {
    'Open': np.random.rand(10) * 100,
    'Close': np.random.rand(10) * 100
}
df = pd.DataFrame(data, index=dates)
print(df.loc['2023-01-03':'2023-01-07', ['Open', 'Close']])
# Out:
#                  Open      Close
# 2023-01-03  26.834142  22.657043
# 2023-01-04  55.207544  77.304681
# 2023-01-05  57.483948  63.117003
# 2023-01-06   7.412739  93.548712
# 2023-01-07  95.416428  87.333509
